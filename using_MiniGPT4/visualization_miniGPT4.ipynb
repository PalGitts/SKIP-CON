# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

! pip install conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
! pip install torch==2.5.1
! pip install bitsandbytes==0.3.0
! pip install transformers==4.49.0
! python3 visualization_miniGPT4.py --cfg-path '/home2/palash/p1_Jailbreak/MiniGPT4/eval_configs/minigpt4_eval.yaml'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -eft (/home2/palash/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/home2/palash/.local/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'pytorch'
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -eft (/home2/palash/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/home2/palash/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -eft (/home2/palash/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/home2/palash/.local/lib/python3.10/site-packages)
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.7.1+cu126

# %%
def list_of_str(arg):
    return list(map(str, arg.split(',')))

parser = eval_parser()
# parser.add_argument("--cfg-path", type=list_of_str, default='/home2/palash/p1_Jailbreak/MiniGPT4/eval_configs/minigpt4_eval.yaml', help="dataset to evaluate")
args = parser.parse_args()
cfg = Config(args)
cfg['cfg-path'] = f'/home2/palash/p1_Jailbreak/MiniGPT4/eval_configs/minigpt4_eval.yaml'

print(cfg)

model, vis_processor = init_model(args)
model.eval()
model = model.cuda().half()  # <-- Convert model to float16 (half precision)

print(f'*********************************')


image_path = './metaphor_0.png'  # replace with your image
question = "What the pile of cigerattes signify here in this context?"
image = Image.open(image_path).convert('RGB')
image_tensor = vis_processor(image).unsqueeze(0).cuda().half()  # <-- Convert image to float16
prompt = f"###Human: <Img><ImageHere></Img> {question} ###Assistant:"
texts = [prompt]

with torch.no_grad():
    output = model.generate(image_tensor, texts, max_new_tokens=50)

print(f'I/P prompt: {prompt}')
print("Answer:", output[0])
# Out:
# usage: ipykernel_launcher.py [-h] --cfg-path CFG_PATH [--name NAME]
#                              [--ckpt CKPT] [--eval_opt EVAL_OPT]
#                              [--max_new_tokens MAX_NEW_TOKENS]
#                              [--batch_size BATCH_SIZE] [--lora_r LORA_R]
#                              [--lora_alpha LORA_ALPHA]
#                              [--options OPTIONS [OPTIONS ...]]
# ipykernel_launcher.py: error: the following arguments are required: --cfg-path
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3450: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
